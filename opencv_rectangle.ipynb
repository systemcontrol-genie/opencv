# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
blank_img = np.zeros((512, 512, 3), dtype = np.int16)
blank_img.shape
# Out:
# (512, 512, 3)

# %%
plt.imshow(blank_img)

# %%
cv2.rectangle(blank_img, pt1=(384, 0), pt2=(510,150) , color=(0,255,0), thickness=10)
plt.imshow(blank_img)

# %%
cv2.rectangle(blank_img, pt1=(200, 200), pt2=(300, 300), color=(255, 0, 0), thickness=20)
plt.imshow(blank_img)

# %%
cv2.circle(blank_img, center=(100,100), radius=50, color=(100, 100, 55), thickness=8)
plt.imshow(blank_img)

# %%
cv2.circle(blank_img, center=(400,400), radius=50 , color = (50, 50, 50), thickness= -1)
plt.imshow(blank_img)

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(blank_img, text="hellow", org=(10,500), fontFace=font, fontScale=4 , color=(255,255,0), thickness=3, lineType=cv2.LINE_AA)
plt.imshow(blank_img)

# %%
blank_img = np.zeros((512,512,3), dtype=np.int32)
vertices  = np.array([[100,300],[200,200],[400,300],[200, 400]], dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
vertices.shape
# Out:
# (4, 2)

# %%
pts = vertices.reshape((-1,1,2))
pts.shape
# Out:
# (4, 1, 2)

# %%
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv2.polylines(blank_img, [pts], isClosed=True, color=(255,0,0), thickness=5)
plt.imshow(blank_img)

# %%
import numpy as np

img = np.full((400, 400, 3), 255, np.uint8)

cv2.line(img ,(50,50),(200,50),(0,0,255), 5)
cv2.line(img, (50,60), (150,150), (0,0,128))

plt.imshow(img)

# %%
cv2.rectangle(img, (50,200,150,100), (0,255,0),2)
cv2.rectangle(img,(70, 220), (180,280),(0,128,0),-1)
plt.imshow(img)

# %%
cv2.circle(img, (300,100),30 ,(255,255,0), -1 , cv2.LINE_AA)
cv2.circle(img, (300, 100), 60, (255, 0,0), 3, cv2.LINE_AA)

pts = np.array([[250,200],[300,200],[350, 300],[250,300]])

cv2.polylines(img,[pts], True, (255,0,255),2)

plt.imshow(img)
